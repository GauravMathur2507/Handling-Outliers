# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('train1.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ML Models sensitive to Outliers:
# 1. Naive Bayes : Not sensitive
# 2. SVM : Not sensitive
# 3. Linear Regression : Sensitive
# 4. Logistic Regression : Sensitive
# 5. Decision Tree : Not sensitive
# 6. Random Forest, XGBoost, Adaboost : Not sensitive
# 7. KNN : Not Sensitive
# 8. K-Means : Sensitive
# 9. Hierarchial Clustering : Sensitive
# 10. Neural Network : Not sensitive
# 11. PCA : Sensitive

# %%
df['Age'].isnull().sum()
# Out:
# 177

# %%
sns.distplot(df['Age'].dropna())
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df['Age'].fillna(100))
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
#Gaussian Distribution

# %%
figure = df.Age.hist(bins = 50)

# %%
sns.boxplot(df['Age'])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %%
df['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
##Assuming Age follows Gaussian Distribution which differentiates the boundaries

# %% [markdown]
# If The Data Is Normally Distributed We use this

# %%
upper_boundary = df['Age'].mean() + 3* df['Age'].std()

# %%
upper_boundary
# Out:
# 73.27860964406094

# %%
lower_boundary = df['Age'].mean() - 3* df['Age'].std()

# %%
lower_boundary
# Out:
# -13.880374349943303

# %%
##Let's compute the Inter Quantile Range
IQR = df['Age'].quantile(0.75) - df['Age'].quantile(0.25)
IQR
# Out:
# 17.875

# %%
lower_bridge = df['Age'].quantile(0.25) - (IQR)*(1.5)

# %%
upper_bridge = df['Age'].quantile(0.75) + (IQR*1.5)

# %%
lower_bridge, upper_bridge
# Out:
# (-6.6875, 64.8125)

# %%
#### Extreme outliers
lower_bridge=df['Age'].quantile(0.25)-(IQR*3)
upper_bridge=df['Age'].quantile(0.75)+(IQR*3)
print(lower_bridge), print(upper_bridge)
# Out:
# -33.5
# 91.625
# (None, None)

# %% [markdown]
# If Features Are Skewed We Use the below Technique

# %%
df['Fare'].hist(bins = 50)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(df['Fare'])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Fare'>

# %%
df['Fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
upper_boundary = df['Fare'].mean() + 3* df['Fare'].std()
lower_boundary = df['Fare'].mean() - 3* df['Fare'].std()
print(upper_boundary, lower_boundary)
# Out:
# 181.2844937601173 -116.87607782296804

# %%
IQR = df['Fare'].quantile(0.75) - df['Fare'].quantile(0.25)
IQR
# Out:
# 23.0896

# %%
upper_bridge = df['Fare'].quantile(0.75) + (IQR * 1.5)
lower_bridge = df['Fare'].quantile(0.25) - (IQR * 1.5)
print(upper_bridge, lower_bridge)
# Out:
# 65.6344 -26.724

# %%
#### Extreme outliers
lower_bridge=df['Fare'].quantile(0.25)-(IQR*3)
upper_bridge=df['Fare'].quantile(0.75)+(IQR*3)
print(lower_bridge), print(upper_bridge)
# Out:
# -61.358399999999996
# 100.2688
# (None, None)

# %%
data = df.copy()

# %%
data.loc[data['Age']>73, 'Age'] = 73

# %%
data.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
data.loc[data['Fare']>100, 'Fare'] = 100

# %%
data.Fare.hist(bins = 50)
# Out:
# <AxesSubplot:>

# %%
data['Fare_new'] = np.where(data['Fare']>100, 100, data['Fare'])

# %%
data['Fare_new'].hist(bins = 50)
# Out:
# <AxesSubplot:>

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.loc[df['Pclass']>1]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
df.loc[(df.Age > 22) & (df.Pclass > 1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 4              5         0       3
# 8              9         1       3
# 13            14         0       3
# 15            16         1       2
# ..           ...       ...     ...
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 4                             Allen, Mr. William Henry    male  35.0      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.loc[1:3]
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S

# %%
df.loc[(df.Age>12),['PassengerId', 'Fare']]
# Out:
#      PassengerId     Fare
# 0              1   7.2500
# 1              2  71.2833
# 2              3   7.9250
# 3              4  53.1000
# 4              5   8.0500
# ..           ...      ...
# 885          886  29.1250
# 886          887  13.0000
# 887          888  30.0000
# 889          890  30.0000
# 890          891   7.7500
#
# [645 rows x 2 columns]

# %%
df.loc[df.Age > 12,['Survived']] = 1

# %%
df.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         1       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         1       3
# 5             6         0       3
# 6             7         1       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         1       3
# 13           14         1       3
# 14           15         1       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         1       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
df.iloc[[0,2]]
# Out:
#    PassengerId  Survived  Pclass                     Name     Sex   Age  \
# 0            1         1       3  Braund, Mr. Owen Harris    male  22.0
# 2            3         1       3   Heikkinen, Miss. Laina  female  26.0
#
#    SibSp  Parch            Ticket   Fare Cabin Embarked
# 0      1      0         A/5 21171  7.250   NaN        S
# 2      0      0  STON/O2. 3101282  7.925   NaN        S

# %%
df.iloc[[0,2], [1,3]]
# Out:
#    Survived                     Name
# 0         1  Braund, Mr. Owen Harris
# 2         1   Heikkinen, Miss. Laina

# %%
df.iloc[:,1:]
# Out:
#      Survived  Pclass                                               Name  \
# 0           1       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           1       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         1       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         1       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Fare_new
# 0      0         A/5 21171   7.2500   NaN        S    7.2500
# 1      0          PC 17599  71.2833   C85        C   71.2833
# 2      0  STON/O2. 3101282   7.9250   NaN        S    7.9250
# 3      0            113803  53.1000  C123        S   53.1000
# ...

# %%
##Applying Logistic Regression

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data[['Age', 'Fare']].fillna(0), data['Survived'], test_size = 0.2)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = classifier.predict(X_test)
y_pred1=classifier.predict_proba(X_test)

# %%
from sklearn.metrics import accuracy_score, roc_auc_score

# %%
print('Accuracy_score : {}'.format(accuracy_score(y_test, y_pred)))
print('Roc_Auc_Score : {}'.format(roc_auc_score(y_test, y_pred1[:,1])))
# Out:
# Accuracy_score : 0.6256983240223464
# Roc_Auc_Score : 0.6913037942449706

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier()
classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = classifier.predict(X_test)
y_pred1=classifier.predict_proba(X_test)

# %%
print('Accuracy_score : {}'.format(accuracy_score(y_test, y_pred)))
print('Roc_Auc_Score : {}'.format(roc_auc_score(y_test, y_pred1[:,1])))
# Out:
# Accuracy_score : 0.6256983240223464
# Roc_Auc_Score : 0.7081105169340464
